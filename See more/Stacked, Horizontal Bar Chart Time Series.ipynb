# %% [markdown]
# # Stacked, Horizontal Bar Chart Time Series in Plotly

# %% [markdown]
# Inspired by <a href="http://mattbango.com/notebook/code/pure-css-timeline/">http://mattbango.com/notebook/code/pure-css-timeline/</a><br>Questions? jack[at]plot[dot]ly

# %%
import plotly
py = plotly.plotly('IPython.Demo', '1fw3zw2o13')

# %%
categories = ['Design & Typography', 'Photography', 'Web Dev & Programming', \
              '3D Modeling & Rendering', 'Drawing & Illustration'];

first_white_stack = {'name': '',
	'x': categories,
	'y': [2006, 2005, 2003, 2002, 2002],
    'marker':{'color': 'white'},
	'type': 'bar',
    'bardir':'h'}

middle_grey_stack = {'name': '',
	'x': categories,
	'y': [3, 4, 6, 3, 7],
    'marker':{'color': 'lightgrey','line': {'color': 'violet','width': 2}},
	'type': 'bar',
    'bardir':'h'}

last_white_stack = {'name': '',
	'x': categories,
	'y': [0, 0, 0, 4, 0],
    'marker':{'color': 'white'},
	'type': 'bar',
    'bardir':'h'}

text = [
    {'text':'Drawing & Illustration',
     'xref':'x','yref':'y',
     'showarrow': False,
     'font':{'color':'#444'},
     'x':2005.5,'y':4},
    {'text':'3D Modeling & Rendering',
     'xref':'x','yref':'y',
     'showarrow': False,
     'font':{'color':'#444'},
     'x':2003.5,'y':3},
    {'text':'Web Dev & Programming',
     'xref':'x','yref':'y',
     'showarrow': False,
     'font':{'color':'#444'},
     'x':2006,'y':2},
    {'text':'Photography',
     'xref':'x','yref':'y',
     'showarrow': False,
     'font':{'color':'#444'},
     'x':2007,'y':1},  
    {'text':'Design & Typography',
     'xref':'x','yref':'y',
     'showarrow': False,
     'font':{'color':'#444'},
     'x':2007.5,'y':0},     
]

layout = {
    'height' : 300,
    'autosize': False,
    'showlegend': False,
    'annotations': text,
    'xaxis': {'range' : [2002,2009], 'dtick':1, 'tickcolor':'grey', 'autotick':False, \
              'showgrid': False, 'showline': False},
    'yaxis': {'showgrid': False, 'showline': False, 'ticks': '', 'showticklabels': False},
    'barmode': 'stack',
    'margin': {'l': 160},
    'categories': categories}

py.iplot([first_white_stack, middle_grey_stack, last_white_stack], layout=layout, height=300)
# Out:
# <iframe height="350" id="igraph" scrolling="no" seamless="seamless" src="https://plot.ly/~IPython.Demo/1045/600/300" width="650"></iframe>
